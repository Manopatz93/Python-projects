# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df= pd.read_csv("/CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
numbers=[]
for i in df.columns:
  if df[i].dtypes=="int64" or df[i].dtypes=="float64":
    numbers.append(i)
#  or we can use this code to take out int and float
# select columns with integer or float data types
# numeric_cols = df.select_dtypes(include=['int', 'float']).columns

# %%
numbers
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
numeric=df[numbers]
numeric.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
numeric.set_index("car_ID",inplace=True)

# %%
numeric.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#now we gonna do the corelation for the variable and check whether which are all the things impoortant to the dependent variable.

# %%
corr= numeric.corr()
print(corr)
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm',ax=ax)
plt.show()

# %%
cor1 = df.corr()['price'][:-1]

# create a bar chart of the correlation coefficients
plt.figure(figsize=(12, 8))
sns.barplot(x=cor1.index, y=cor1.values)
plt.title('Correlation coefficients with y')
plt.xticks(rotation='vertical')
plt.show()

# %%
# so from this bar chart we can clearly say the id and symboling and pearkrpm have no co relation with respect to the car price
# we can drop it ,
# important points to understand here is , 

# why city mpg and highway mpg are inversely to price , because we can say that if the millege is less( obviosuly its super cars) price inreases

# %%
numeric.reset_index(inplace=True)
numeric.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
numeric.drop(columns=["car_ID","symboling","peakrpm"],inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
numeric.head()
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
# 1       88.6      168.8      64.1       48.8        2548         130
# 2       94.5      171.2      65.5       52.4        2823         152
# 3       99.8      176.6      66.2       54.3        2337         109
# 4       99.4      176.6      66.4       54.3        2824         136
#
#    boreratio  stroke  compressionratio  horsepower  citympg  highwaympg  \
# 0       3.47    2.68               9.0         111       21          27
# 1       3.47    2.68               9.0         111       21          27
# 2       2.68    3.47               9.0         154       19          26
# 3       3.19    3.40              10.0         102       24          30
# 4       3.19    3.40               8.0         115       18          22
#
#      price
# 0  13495.0
# 1  16500.0
# 2  16500.0
# 3  13950.0
# 4  17450.0

# %%
X= numeric.drop(["price"],axis=1)
y=numeric["price"]

# %%
# MODELLING

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 6802.77169892, 20276.2123695 , 14741.87451054, -1076.25885619,
#        10953.20959199, 13857.79118571,  5363.30926287,  6838.91639332,
#        23105.93230712,  7197.3548652 , 17694.59016369, 38194.26429036,
#         8750.05267774, 14256.42268637,  5432.45222789, 13680.03448187,
#        10709.88190599, 18451.11551084,  9040.93348333,  6875.15482754,
#        10958.05225363, 17800.76341412, 10555.48134715, 13906.39653442,
#        22191.63932744,  7941.35440122,  7478.76604838, 17464.23213627,
#         7607.4828605 ,  5853.90015796,  9655.05352194, 10524.73205368,
#        20028.03414425, 10671.7138013 ,  5921.94764615, 26057.81177794,
#         9977.83157482, 17189.92764008,  6236.30297099, 37327.03206071,
#         5383.84687919])

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print('R-squared score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 14618980.84
# R-squared score: 0.81

# %%
df_pred = pd.DataFrame({'Y_pred': y_pred})

# concatenate with original dataframe containing input variables
numeric = pd.concat([X_test.reset_index(drop=True), y_test.reset_index(drop=True), df_pred], axis=1)

# %%
numeric
# Out:
#     wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0        93.1      159.1      64.2       54.1        1905          91
# 1       104.5      187.8      66.5       54.1        3151         161
# 2        99.8      177.3      66.3       53.1        2507         136
# 3        88.4      141.1      60.3       53.2        1488          61
# 4        97.3      171.7      65.5       55.7        2300         109
# 5        98.4      176.2      65.6       52.0        2679         146
# 6        93.7      157.3      64.4       50.8        1918          92
# 7        95.7      169.7      63.6       59.1        2290          92
# 8        91.3      170.7      67.9       49.7        3071         181
# 9        93.7      150.0      64.0       52.6        1940          92
# 10      101.2      176.8      64.8       54.3        2710         164
# 11       98.4      175.7      72.3       50.5        3366         203
# ...

# %%
# as we can see there is huge error rate captured during this process while we considering the only int and floar datatypes
# so we gonna consider the object data type feature and gonna convert into categorical or dummy variables to train the ml model

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
CompanyName = df['CarName'].apply(lambda x : x.split(' ')[0])
model=df['CarName'].apply(lambda x : x.split(' ')[-1])

# %%
df.insert(3,"CompanyName",CompanyName)
df.insert(4,"Model",model)

df.head()
# Out:
#    car_ID  symboling                   CarName  CompanyName         Model  \
# 0       1          3        alfa-romero giulia  alfa-romero        giulia
# 1       2          3       alfa-romero stelvio  alfa-romero       stelvio
# 2       3          1  alfa-romero Quadrifoglio  alfa-romero  Quadrifoglio
# 3       4          2               audi 100 ls         audi            ls
# 4       5          2                audi 100ls         audi         100ls
#
#   fueltype aspiration doornumber      carbody drivewheel  ... enginesize  \
# 0      gas        std        two  convertible        rwd  ...        130
# 1      gas        std        two  convertible        rwd  ...        130
# 2      gas        std        two    hatchback        rwd  ...        152
# 3      gas        std       four        sedan        fwd  ...        109
# 4      gas        std       four        sedan        4wd  ...        136
#
#    fuelsystem  boreratio  stroke  compressionratio  horsepower peakrpm  \
# ...

# %%
df["CompanyName"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df.CompanyName= df.CompanyName.str.lower()

# %%
df.CompanyName.replace('maxda','mazda',inplace=True)

# %%
def replace_name(a,b):
    df.CompanyName.replace(a,b,inplace=True)

# %%
replace_name('maxda','mazda')
replace_name('porcshce','porsche')
replace_name('toyouta','toyota')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

# %%
df["CompanyName"].nunique()
# Out:
# 22

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, CompanyName, Model, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 28 columns]

# %%
#Fuel economy
df['fueleconomy'] = (0.55 * df['citympg']) + (0.45 * df['highwaympg'])

# %%
#Binning the Car Companies based on avg prices of each Company.
df['price'] = df['price'].astype('int')
temp = df.copy()
table = temp.groupby(['CompanyName'])['price'].mean()
temp = temp.merge(table.reset_index(), how='left',on='CompanyName')
bins = [0,10000,20000,40000]
cars_bin=['Budget','Medium','Highend']
df['carsrange'] = pd.cut(temp['price_y'],bins,right=False,labels=cars_bin)
df.head()
# Out:
#    car_ID  symboling                   CarName  CompanyName         Model  \
# 0       1          3        alfa-romero giulia  alfa-romero        giulia
# 1       2          3       alfa-romero stelvio  alfa-romero       stelvio
# 2       3          1  alfa-romero Quadrifoglio  alfa-romero  Quadrifoglio
# 3       4          2               audi 100 ls         audi            ls
# 4       5          2                audi 100ls         audi         100ls
#
#   fueltype aspiration doornumber      carbody drivewheel  ... boreratio  \
# 0      gas        std        two  convertible        rwd  ...      3.47
# 1      gas        std        two  convertible        rwd  ...      3.47
# 2      gas        std        two    hatchback        rwd  ...      2.68
# 3      gas        std       four        sedan        fwd  ...      3.19
# 4      gas        std       four        sedan        4wd  ...      3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg highwaympg  price  \
# ...

# %%
cars_lr = df[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'fueleconomy', 'carlength','carwidth', 'carsrange']]
cars_lr.head()
# Out:
#    price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495      gas        std  convertible        rwd       88.6        2548
# 1  16500      gas        std  convertible        rwd       88.6        2548
# 2  16500      gas        std    hatchback        rwd       94.5        2823
# 3  13950      gas        std        sedan        fwd       99.8        2337
# 4  17450      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  fueleconomy  \
# 0       dohc           four         130       3.47         111        23.70
# 1       dohc           four         130       3.47         111        23.70
# 2       ohcv            six         152       2.68         154        22.15
# 3        ohc           four         109       3.19         102        26.70
# 4        ohc           five         136       3.19         115        19.80
#
#    carlength  carwidth carsrange
# ...

# %%
# Defining the map function
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr

cars_lr = dummies('fueltype',cars_lr)
cars_lr = dummies('aspiration',cars_lr)
cars_lr = dummies('carbody',cars_lr)
cars_lr = dummies('drivewheel',cars_lr)
cars_lr = dummies('enginetype',cars_lr)
cars_lr = dummies('cylindernumber',cars_lr)
cars_lr = dummies('carsrange',cars_lr)

# %%
cars_lr.columns
# Out:
# Index(['price', 'wheelbase', 'curbweight', 'enginesize', 'boreratio',
#        'horsepower', 'fueleconomy', 'carlength', 'carwidth', 'gas', 'turbo',
#        'hardtop', 'hatchback', 'sedan', 'wagon', 'fwd', 'rwd', 'dohcv', 'l',
#        'ohc', 'ohcf', 'ohcv', 'rotor', 'five', 'four', 'six', 'three',
#        'twelve', 'two', 'Medium', 'Highend'],
#       dtype='object')

# %%
X= cars_lr.drop(columns="price",axis=1)
y=cars_lr["price"]

# %%
X.head()
# Out:
#    wheelbase  curbweight  enginesize  boreratio  horsepower  fueleconomy  \
# 0       88.6        2548         130       3.47         111        23.70
# 1       88.6        2548         130       3.47         111        23.70
# 2       94.5        2823         152       2.68         154        22.15
# 3       99.8        2337         109       3.19         102        26.70
# 4       99.4        2824         136       3.19         115        19.80
#
#    carlength  carwidth  gas  turbo  ...  ohcv  rotor  five  four  six  three  \
# 0      168.8      64.1    1      0  ...     0      0     0     1    0      0
# 1      168.8      64.1    1      0  ...     0      0     0     1    0      0
# 2      171.2      65.5    1      0  ...     1      0     0     0    1      0
# 3      176.6      66.2    1      0  ...     0      0     0     1    0      0
# 4      176.6      66.4    1      0  ...     0      0     1     0    0      0
#
#    twelve  two  Medium  Highend
# ...

# %%
y.head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('MSE:', mse)
print('MAE:', mae)
print('R-squared:', r2)
# Out:
# MSE: 11751603.966058053
# MAE: 2255.9952014702408
# R-squared: 0.8482021074655093

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
cars_lr['y_pred'] = y_pred

# %%
cars_lr.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495       88.6        2548         130       3.47         111
# 1  16500       88.6        2548         130       3.47         111
# 2  16500       94.5        2823         152       2.68         154
# 3  13950       99.8        2337         109       3.19         102
# 4  17450       99.4        2824         136       3.19         115
#
#    fueleconomy  carlength  carwidth  gas  ...  rotor  five  four  six  three  \
# 0        23.70      168.8      64.1    1  ...      0     0     1    0      0
# 1        23.70      168.8      64.1    1  ...      0     0     1    0      0
# 2        22.15      171.2      65.5    1  ...      0     0     0    1      0
# 3        26.70      176.6      66.2    1  ...      0     0     1    0      0
# 4        19.80      176.6      66.4    1  ...      0     1     0    0      0
#
#    twelve  two  Medium  Highend        y_pred
# 0       0    0       1        0  13629.178762
# ...

# %%
cars_lr["error"]=cars_lr["price"]-cars_lr["y_pred"]

# %%
cars_lr.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495       88.6        2548         130       3.47         111
# 1  16500       88.6        2548         130       3.47         111
# 2  16500       94.5        2823         152       2.68         154
# 3  13950       99.8        2337         109       3.19         102
# 4  17450       99.4        2824         136       3.19         115
#
#    fueleconomy  carlength  carwidth  gas  ...  five  four  six  three  twelve  \
# 0        23.70      168.8      64.1    1  ...     0     1    0      0       0
# 1        23.70      168.8      64.1    1  ...     0     1    0      0       0
# 2        22.15      171.2      65.5    1  ...     0     0    1      0       0
# 3        26.70      176.6      66.2    1  ...     0     1    0      0       0
# 4        19.80      176.6      66.4    1  ...     1     0    0      0       0
#
#    two  Medium  Highend        y_pred        error
# ...
